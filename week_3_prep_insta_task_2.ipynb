# %% [markdown]
# <a href="https://colab.research.google.com/github/devhinged/PrepInsta-internship/blob/main/week_3_prep_insta_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('chipotle.csv')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      $2.39
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df[df.duplicated()]
# Out:
#       order_id  quantity                            item_name  \
# 238        103         1                        Steak Burrito
# 248        108         1                          Canned Soda
# 297        129         1                        Steak Burrito
# 381        165         1                    Canned Soft Drink
# 484        205         1                         Chicken Bowl
# 567        233         1                    Canned Soft Drink
# 617        254         1                                Chips
# 684        282         1                    Canned Soft Drink
# 773        319         1                         Chicken Bowl
# 908        376         1                        Steak Burrito
# 924        381         1                   Chicken Soft Tacos
# 1003       412         1                        Bottled Water
# 1117       462         1                      Chicken Burrito
# 1203       491         1                      Chicken Burrito
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      $2.39
# ...

# %%
df['quantity'] = pd.to_numeric(df['quantity'])
df['item_price'] = df['item_price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df['choice_description'] = df['choice_description'].astype(str)
df['choice_description']
# Out:
# 0                                                     nan
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     nan
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4563, dtype: object

# %%
df['item_name'] = df['item_name'].str.replace(r'[^\x00-\x7F]+', '', regex=True)

# %%
df['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4563, dtype: object

# %%
df['choice_description'] = df['choice_description'].str.replace(r'[^\x00-\x7F]+', '', regex=True)

# %%
df['choice_description']
# Out:
# 0                                                     nan
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     nan
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4563, dtype: object

# %%
print("\nOrder ID integrity:")
print(df['order_id'].value_counts())
# Out:
# Order ID integrity:
# 926     21
# 1483    14
# 1786    11
# 759     11
# 691     11
#         ..
# 94       1
# 1374     1
# 837      1
# 831      1
# 528      1
# Name: order_id, Length: 1834, dtype: int64

# %%
df['item_name'] = df['item_name'].str.lower()

# %%
df.groupby('quantity')['item_price'].mean()
# Out:
# quantity
# 1      7.199288
# 2     11.843393
# 3     13.373571
# 4     13.096000
# 5      7.500000
# 7     10.500000
# 8     13.520000
# 10    15.000000
# 15    44.250000
# Name: item_price, dtype: float64

# %%
df.groupby('item_name').agg({'quantity': 'sum', 'item_price': 'mean'})
# Out:
#                                        quantity  item_price
# item_name
# 6 pack soft drink                            55    6.610185
# barbacoa bowl                                65   10.201692
# barbacoa burrito                             90    9.838889
# barbacoa crispy tacos                        12   10.928182
# barbacoa salad bowl                           9   10.778889
# barbacoa soft tacos                          25   10.018400
# bottled water                               204    1.884258
# bowl                                          4   14.800000
# burrito                                       6    7.400000
# canned soda                                 124    1.325098
# canned soft drink                           340    1.465517
# carnitas bowl                                71   10.833971
# carnitas burrito                             60   10.132712
# carnitas crispy tacos                         8   11.137143
# ...

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           chips and fresh tomato salsa
# 1            1         1                                   izze
# 2            1         1                       nantucket nectar
# 3            1         1  chips and tomatillo-green chili salsa
# 4            2         2                           chicken bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          steak burrito
# 4618      1833         1                          steak burrito
# 4619      1834         1                     chicken salad bowl
# 4620      1834         1                     chicken salad bowl
# 4621      1834         1                     chicken salad bowl
#
#                                      choice_description  item_price
# 0                                                   nan        2.39
# ...

# %%
df.isnull().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64
